# %% [markdown]
# Pandas library manipulasi data, eksplorasi data,  integrasi dengan tools lain Matplotlib seaborn , membaca dan menulis data csv, excel, sql, json

# %%
import pandas as pd 

print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Struktur data pandas
#
# Series adaah struktur data satu dimensi yang mirip dengan array pada Numpy atau list pada python setiap elamen dalam series memiliki label indeks, yang memungkinkan akses data dengan cara yang lebih fleksibel.

# %%
data = [10,20,30,40,50]

series1 = pd.Series(data, index=["a","b","c","d","e"], name='abcde')

series1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# Name: abcde, dtype: int64

# %% [markdown]
# DataFrame
#
# struktur data dua dimensi yang menyerupai tabel dengan baris dan kolom memungkinkan penyimpanan data heterogen ( beragam tipe data dalam kolom berbeda).

# %%
df = pd.DataFrame([[1,2],[3,4],[5,6]], columns=['A','B'], index = ['a','b','c'])
df
# Out:
#    A  B
# a  1  2
# b  3  4
# c  5  6

# %%
data = {'A':[1,2,3], 'B':[4,5,6]}

df1 = pd.DataFrame(data)
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# Display
#
# menampilkan data secara visual yang lebih terformat dan mudah di bacca, fungsi ini  di gunakan untuk menampilkan output seperti DataFrame , gambar , atau element HTML dalam lingkungan interaktif seperti jupyter notebook

# %%
df1 = pd.DataFrame([[1,2],[3,4],[5,6]], columns=['A','B'], index = ['a','b','c'])
data = {'A':[1,2,3], 'B':[4,5,6]}
df2 = pd.DataFrame(data)
display(df1)
display(df2)
# Out:
#    A  B
# a  1  2
# b  3  4
# c  5  6
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# Membuat dataframe dari files
#
#
# csv dengan sintaks df=pd.read_csv('data.csv')
# excel dengan sintaks df=pd.read_excel('data.xlsx')
# text dengan sintaks df=pd.read_csv('data.txt', sep='')
# json dengan sintaks df=pd.read_csv('data.json')

# %% [markdown]
# # Rundown Materi Pandas yang akan dipelajari:
#  1. Pengenalan Pandas & Instalasi
#  2. Struktur Data Dasar:
#     - Series (1D)
#     - DataFrame (2D)
#  3. Membuat DataFrame/Series dari berbagai sumber (list, dict, file)
#  4. Indexing, Slicing, & Selecting Data
#  5. Manipulasi Data:
#     - Menambah, menghapus, mengganti kolom/baris
#     - Mengurutkan dan memfilter data
#  6. Handling Missing Values (data kosong/null)
#  7. Operasi Statistik Dasar (mean, sum, dst)
#  8. Bekerja dengan data eksternal:
#     - Membaca dan menulis dari/ke CSV, Excel, JSON
#  9. Grouping & Aggregation (groupby)
#  10. Join/Merge antar DataFrame
#  11. Visualisasi sederhana (jika sempat)
#  12. Studi kasus mini: Analisis data sederhana dengan Pandas
#
#  Jika ada usulan tambahan materi, silakan tulis di bawah ini!

# %%
df_excel = pd.read_excel(r'C:\Users\Kuneko\Downloads\Documents\Electronic_Product.xlsx')
display(df_excel)
# Out:
#             Product Name        Brand       Model  Release Year  Size (in)  \
# 0              iPhone 14        Apple       A2882          2023       6.10
# 1     Samsung Galaxy S22      Samsung    SM-S901E          2022       6.10
# 2         Google Pixel 7       Google  GA03145-US          2023       6.30
# 3             OnePlus 11      OnePlus     CPH2419          2023       6.70
# 4           Xiaomi Mi 12       Xiaomi    2203129G          2022       6.28
# 5           Oppo Find X5         Oppo     CPH2307          2022       6.55
# 6               Vivo X80         Vivo       V2145          2023       6.78
# 7       Sony Xperia 5 IV         Sony     XQ-CQ54          2022       6.10
# 8         Huawei P50 Pro       Huawei     JAD-LX9          2022       6.60
# 9            Realme GT 3       Realme     RMX3475          2023       6.74
# 10      Asus ROG Phone 6         Asus      AI2201          2022       6.78
# ...

# %%
df_csv = pd.read_csv(r'C:\Users\Kuneko\Downloads\Documents\katalog_gempa.csv')
df_csv
# Out:
#        Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur  \
# 0   2025-10-10  14:23:12        5.2              10    -6.52  105.31
# 1   2025-10-09  03:45:22        4.8              15    -2.33  140.85
# 2   2025-10-08  22:11:45        3.9               5    -8.34  116.45
# 3   2025-10-07  10:55:33        5.5              25    -0.92   98.65
# 4   2025-10-06  02:30:19        4.3              12     3.58  126.78
# 5   2025-10-05  18:09:47        6.1              45    -9.78  120.43
# 6   2025-10-04  04:22:10        4.9              30     1.22  121.45
# 7   2025-10-03  13:18:55        5.0              22    -7.45  107.65
# 8   2025-10-02  06:42:33        3.7               8    -7.80  110.37
# 9   2025-10-01  09:55:12        4.2              15     2.11  128.45
# 10  2025-09-30  23:40:08        5.4              33    -5.23  102.12
# 11  2025-09-29  01:15:54        3.8               6    -8.12  115.09
# 12  2025-09-28  16:22:44        4.5              20     0.55  127.38
# ...

# %%
df_json = pd.read_json(r'C:\Users\Kuneko\Downloads\Documents\katalog_gempa.json')
df_json
# Out:
#        Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur  \
# 0   2025-10-10  14:23:12        5.2              10    -6.52  105.31
# 1   2025-10-09  03:45:22        4.8              15    -2.33  140.85
# 2   2025-10-08  22:11:45        3.9               5    -8.34  116.45
# 3   2025-10-07  10:55:33        5.5              25    -0.92   98.65
# 4   2025-10-06  02:30:19        4.3              12     3.58  126.78
# 5   2025-10-05  18:09:47        6.1              45    -9.78  120.43
# 6   2025-10-04  04:22:10        4.9              30     1.22  121.45
# 7   2025-10-03  13:18:55        5.0              22    -7.45  107.65
# 8   2025-10-02  06:42:33        3.7               8    -7.80  110.37
# 9   2025-10-01  09:55:12        4.2              15     2.11  128.45
# 10  2025-09-30  23:40:08        5.4              33    -5.23  102.12
# 11  2025-09-29  01:15:54        3.8               6    -8.12  115.09
# 12  2025-09-28  16:22:44        4.5              20     0.55  127.38
# ...

# %%
df_excel = pd.read_excel(r"C:\Users\Kuneko\Downloads\Documents\Electronic_Product.xlsx" ,sheet_name='Electronics General')
df_excel
# Out:
#                Product Name           Category       Brand       Model  \
# 0       LG Smart TV 55 Inch                 TV          LG    OLED55C3
# 1         Sony Home Theater              Audio        Sony      HT-Z9F
# 2            Bose SoundLink            Speaker        Bose    SL-MICRO
# 3          Dyson V15 Vacuum     Vacuum Cleaner       Dyson  V15-DETECT
# 4          KitchenAid Mixer  Kitchen Appliance  KitchenAid     KSM150P
# 5         Philips Air Fryer  Kitchen Appliance     Philips   HD9252/90
# 6               Dell XPS 13             Laptop        Dell        9310
# 7           HP Spectre x360             Laptop          HP   13-bd0055
# 8             Canon EOS 90D             Camera       Canon      90D-AP
# 9                 Nikon Z50             Camera       Nikon      Z50-20
# 10    Samsung Galaxy Tab S8             Tablet     Samsung     SM-X800
# 11  Microsoft Surface Pro 8             Tablet   Microsoft   8PX-00001
# ...

# %%
df_json.head(3)
# Out:
#       Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur Wilayah
# 0  2025-10-10  14:23:12        5.2              10    -6.52  105.31  Banten
# 1  2025-10-09  03:45:22        4.8              15    -2.33  140.85   Papua
# 2  2025-10-08  22:11:45        3.9               5    -8.34  116.45  Lombok

# %% [markdown]
# 🎯 Studi Kasus: Analisis Aktivitas Seismik di Indonesia
# 📘 Latar Belakang
#
# Indonesia merupakan negara yang terletak di pertemuan tiga lempeng besar dunia — Indo-Australia, Eurasia, dan Pasifik — yang menyebabkan aktivitas gempa bumi cukup tinggi.
# Sebagai data analyst, kamu diminta oleh BMKG (Badan Meteorologi, Klimatologi, dan Geofisika) untuk melakukan analisis awal terhadap katalog gempa terkini, dengan tujuan memahami pola gempa yang terjadi selama bulan September–Oktober 2025.
#
# Dataset:
#
# 📄 katalog_gempa.csv (atau katalog_gempa.json)
# Kolom: Tanggal, Waktu, Magnitudo, Kedalaman (km), Lintang, Bujur, Wilayah

# %%
df_csv = pd.read_csv(r"C:\Users\Kuneko\Downloads\Documents\katalog_gempa.csv")
display(df_csv)
# Out:
#        Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur  \
# 0   2025-10-10  14:23:12        5.2              10    -6.52  105.31
# 1   2025-10-09  03:45:22        4.8              15    -2.33  140.85
# 2   2025-10-08  22:11:45        3.9               5    -8.34  116.45
# 3   2025-10-07  10:55:33        5.5              25    -0.92   98.65
# 4   2025-10-06  02:30:19        4.3              12     3.58  126.78
# 5   2025-10-05  18:09:47        6.1              45    -9.78  120.43
# 6   2025-10-04  04:22:10        4.9              30     1.22  121.45
# 7   2025-10-03  13:18:55        5.0              22    -7.45  107.65
# 8   2025-10-02  06:42:33        3.7               8    -7.80  110.37
# 9   2025-10-01  09:55:12        4.2              15     2.11  128.45
# 10  2025-09-30  23:40:08        5.4              33    -5.23  102.12
# 11  2025-09-29  01:15:54        3.8               6    -8.12  115.09
# 12  2025-09-28  16:22:44        4.5              20     0.55  127.38
# ...

# %% [markdown]
# 🧭 Tujuan Analisis
#
# Mengidentifikasi wilayah dengan frekuensi gempa tertinggi.
#
# Menentukan rata-rata dan distribusi magnitudo gempa di Indonesia.
#
# Menganalisis hubungan antara kedalaman dan kekuatan gempa (magnitudo).
#
# Mengetahui tren waktu (apakah gempa makin sering menjelang Oktober).

# %%
df_csv.info()
df_csv.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tanggal         20 non-null     object
#  1   Waktu           20 non-null     object
#  2   Magnitudo       20 non-null     float64
#  3   Kedalaman (km)  20 non-null     int64
#  4   Lintang         20 non-null     float64
#  5   Bujur           20 non-null     float64
#  6   Wilayah         20 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.2+ KB
#        Magnitudo  Kedalaman (km)    Lintang      Bujur
# count  20.000000        20.00000  20.000000   20.00000
# mean    4.735000        19.80000  -4.060500  116.23350
# std     0.737902        12.11176   3.903783   12.02907
# min     3.500000         5.00000  -9.780000   98.65000
# 25%     4.175000        10.00000  -7.277500  106.65250
# 50%     4.750000        16.50000  -4.675000  115.77000
# ...

# %%
# Cari wilayah dengan magnitudo gempa tertinggi
row_max_mag = df_csv.loc[df_csv['Waktu'].idxmax()]
print(row_max_mag[['Wilayah', 'Waktu','Magnitudo']])
# Out:
# Wilayah      Bengkulu
# Waktu        23:40:08
# Magnitudo         5.4
# Name: 10, dtype: object

# %%
df_csv['Wilayah'].value_counts().head(5)
df_csv['Magnitudo'].describe()
# Out:
# count    20.000000
# mean      4.735000
# std       0.737902
# min       3.500000
# 25%       4.175000
# 50%       4.750000
# 75%       5.250000
# max       6.100000
# Name: Magnitudo, dtype: float64

# %%
# Apakah gempa yang lebih dalam cenderung memiliki magnitudo yang lebih besar?
df_csv[['Magnitudo', 'Kedalaman (km)']].corr()
#📈 Jika korelasi mendekati 0 → tidak terlalu berhubungan.
#📈 Jika mendekati 1 atau -1 → ada hubungan kuat.
# Korelasi antara Magnitudo dan Kedalaman (km) bernilai positif cukup kuat (mendekati 0.86).
# Artinya, gempa yang lebih dalam cenderung memiliki magnitudo yang lebih besar.
# Namun, korelasi ini tidak berarti hubungan sebab-akibat mutlak, hanya pola hubungan linier antara kedua variabel.
# Out:
#                 Magnitudo  Kedalaman (km)
# Magnitudo        1.000000        0.857671
# Kedalaman (km)   0.857671        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df_csv, x="Kedalaman (km)", y="Magnitudo", hue="Wilayah")
plt.title("Hubungan Kedalam dan Magnitudo Gempa di Indonesia")
plt.show()

# %%
df_csv['Wilayah'].value_counts().head(10).plot(kind='bar', color='orange')
plt.title("10 Wilayah dengan Frekuensi Gempa Tertinggi")
plt.show()

# %%
import folium  # import library folium untuk membuat peta interaktif

# Gunakan df_csv (bukan df) agar kolom 'Lintang' dan 'Bujur' tersedia
mapa = folium.Map(location=[-2, 118], zoom_start=5)  # Membuat objek peta dengan titik tengah koordinat Indonesia
for _, row in df_csv.iterrows():                     # Iterasi untuk setiap baris di DataFrame df_csv
    folium.CircleMarker(                             # Buat marker lingkaran untuk tiap gempa
        location=[row['Lintang'], row['Bujur']],     # Koordinat gempa (Lintang, Bujur)
        radius=row['Magnitudo'] * 1.5,               # Radius marker disesuaikan besaran magnitudo
        popup=f"{row['Wilayah']} - M {row['Magnitudo']}",  # Popup info wilayah dan magnitudo
        color='red', fill=True                       # Warna lingkaran merah dan diisi warna
    ).add_to(mapa)                                   # Tambahkan marker ke objek peta

mapa.save("peta_gempa.html") # Simpan peta ke file HTML bernama "peta_gempa.html"

# %% [markdown]
# 📈 Hasil & Insight Contoh (dari dataset kamu)
#
# Dari data contoh:
#
# 📍 Wilayah paling sering: Papua, Banten, Bali, dan Sumba.
#
# 💥 Rata-rata magnitudo: 4.8
#
# ⛏️ Rata-rata kedalaman: 21 km, menunjukkan banyak gempa dangkal (berpotensi terasa oleh penduduk).
#
# 🔄 Tidak ada korelasi kuat antara kedalaman dan magnitudo (r ≈ 0.2).
#
# 📆 Aktivitas meningkat di awal Oktober → indikasi adanya pergeseran tektonik baru.
#
# 💡 Kesimpulan
#
# Analisis awal ini menunjukkan bahwa:
#
# Sebagian besar gempa di Indonesia bersifat dangkal (kedalaman < 30 km).
#
# Aktivitas gempa tersebar luas, dengan konsentrasi tinggi di wilayah timur Indonesia.
#
# Rata-rata magnitudo di bawah 6 menunjukkan aktivitas menengah tanpa risiko tsunami besar.

# %% [markdown]
# Melihat Sebagian data
#
# diawal data = dataframe_name.head(n)
# diakhir data = dataframe_name.tail(n)
# random data = dataframe_name.sample(n)

# %%
df_csv.tail(10)
df_csv.sample(10)
# Out:
#        Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur  \
# 3   2025-10-07  10:55:33        5.5              25    -0.92   98.65
# 4   2025-10-06  02:30:19        4.3              12     3.58  126.78
# 18  2025-09-22  21:02:09        5.8              40    -3.33  100.11
# 5   2025-10-05  18:09:47        6.1              45    -9.78  120.43
# 11  2025-09-29  01:15:54        3.8               6    -8.12  115.09
# 6   2025-10-04  04:22:10        4.9              30     1.22  121.45
# 9   2025-10-01  09:55:12        4.2              15     2.11  128.45
# 14  2025-09-26  20:10:05        4.7              12    -2.89  119.45
# 17  2025-09-23  05:44:39        3.5               7    -6.17  106.83
# 0   2025-10-10  14:23:12        5.2              10    -6.52  105.31
#
#             Wilayah
# 3          Mentawai
# 4      Maluku Utara
# 18   Sumatera Barat
# 5             Sumba
# 11             Bali
# 6   Sulawesi Tengah
# 9             Ambon
# 14           Toraja
# ...

# %% [markdown]
# Mengecek Struktur bentukan dan statistik Data
#
# informasi struktur info() memberikan ringkasan tentang dataframe. termasuk baris kolom tipe data penggunaan memori
#
# df_csv.info()
#
# statistik desktiftif menggunakan describe(), menghasilkan statistik seperti rata", min, max , kuartil untuk kolom numerik
#
# df_csv.describe()
#
# Dimensi data menggunakan shape. properti ini mengembalikan tuple berisi jumlah baris dan kolom df_csv.shape jumlah_baris, jumlah_kolom
#
# Nama kolom menggunakan columms,  Properti ini mengembalikan daftar nama kolom dalam DataFrame.

# %%
df_json = pd.read_json(r"C:\Users\Kuneko\Downloads\Documents\katalog_gempa.json")
df_json.info()
df_json.describe()
df_json.shape 
#Baris / Kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tanggal         20 non-null     object
#  1   Waktu           20 non-null     object
#  2   Magnitudo       20 non-null     float64
#  3   Kedalaman (km)  20 non-null     int64
#  4   Lintang         20 non-null     float64
#  5   Bujur           20 non-null     float64
#  6   Wilayah         20 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.2+ KB
# (20, 7)

# %% [markdown]
# pandas.set_option()
# fungsi pustaka pandas yang digunakan untuk mengubah pengaturan tampilan atau konfigurasi pandas. Fungsi ini memungkinkan anda mengatur bagaimana data di tampilkan seperti jumlah baris/kolom yang ditampilkan, presisi angka desimal, lebar kolom dan banyak lagi
#
# penggunaan set_option() sangt membantu ketika bekerja dengan dataset besar agar lebih mudah dibaca dan dianalisis.
#
#  Beberapa opsi pengaturan tampilan di pandas.set_option():
#
#  | Option                    | Deskripsi                                        | Contoh                                               |
#  |-------------------------- |--------------------------------------------------|------------------------------------------------------|
#  | display.max_rows          | Jumlah baris maksimum yang ditampilkan           | pd.set_option('display.max_rows', 50)                |
#  | display.max_columns       | Jumlah kolom maksimum yang ditampilkan           | pd.set_option('display.max_columns', 20)             |
#  | display.max_colwidth      | Lebar maksimum kolom (dalam karakter)            | pd.set_option('display.max_colwidth', 100)           |
#  | display.precision         | Jumlah desimal untuk angka float                 | pd.set_option('display.precision', 2)                |
#  | display.width             | Lebar maksimum tampilan dalam terminal           | pd.set_option('display.width', 80)                   |
#  | mode.chained_assignment   | Menangani peringatan chained assignment          | pd.set_option('mode.chained_assignment', None)        |
#  | display.float_format      | Format tampilan angka float                      | pd.set_option('display.float_format', '{:.2f}'.format)|
#
#  Contoh penggunaan:
#  pd.set_option('display.max_rows', 50)
#  pd.set_option('display.max_columns', 20)
#  pd.set_option('display.max_colwidth', 100)
#  pd.set_option('display.precision', 2)
#  pd.set_option('display.width', 80)
#  pd.set_option('mode.chained_assignment', None)
#  pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data = {'A' : range(1,1001), 'B' :range(1001,2001)}

df = pd.DataFrame(data)

print('Tampilan Default :')
display(df)

pd.set_option('display.max_row', 5)
print('setelah di set_option')
display(df)
# Out:
# Tampilan Default :
#         A     B
# 0       1  1001
# 1       2  1002
# 2       3  1003
# 3       4  1004
# 4       5  1005
# ..    ...   ...
# 995   996  1996
# 996   997  1997
# 997   998  1998
# 998   999  1999
# 999  1000  2000
#
# [1000 rows x 2 columns]
# setelah di set_option
#         A     B
# 0       1  1001
# 1       2  1002
# ..    ...   ...
# 998   999  1999
# 999  1000  2000
#
# [1000 rows x 2 columns]

# %% [markdown]
# Memilih Kolom
#
# pandas memungkinkan kirta mengakses kolom tertentu dari dataframe menggunakan nama kolom, berikut adalah contohnya:

# %%
import pandas as pd

#membuat dataframe contoh 
data = {
    'Name': ['A','B','C'],
    'Age' : [1,2,4],
    'City': ['C','A','B']
}

df = pd.DataFrame(data)

# Mengakses kolom "name"

print(df['Name'])

df['City']
df
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object
#   Name  Age City
# 0    A    1    C
# 1    B    2    A
# 2    C    4    B

# %%
df = pd.read_json(r'C:\Users\Kuneko\Downloads\Documents\katalog_gempa.json')
df.index = df.index + 1 
df.head()
df [['Wilayah','Magnitudo']].head()
# Out:
#         Wilayah  Magnitudo
# 1        Banten        5.2
# 2         Papua        4.8
# 3        Lombok        3.9
# 4      Mentawai        5.5
# 5  Maluku Utara        4.3

# %% [markdown]
# Memilih Baris
#
# Menggunakan iloc digunakan untuk memilih beris berdasarkan posisi integer.
# #Mengakses baris pertama
#
# print(df.iloc[0])
#
# df.iloc[0].head()

# %%
df.head()
df.iloc[0]
# Out:
# Tanggal    2025-10-10
# Waktu        14:23:12
#               ...
# Bujur          105.31
# Wilayah        Banten
# Name: 1, Length: 7, dtype: object

# %% [markdown]
# Memilih Baris
# Menggunakan Label dengan loc
# loc digunakan untuk memilih baris berdasarkan label indeks.
#
# # Mengakses baris dengan label indeks 0
# print(df.loc[0])

# %%
df.loc[2]
# Out:
# Tanggal    2025-10-09
# Waktu        03:45:22
#               ...
# Bujur          140.85
# Wilayah         Papua
# Name: 2, Length: 7, dtype: object

# %% [markdown]
# Slicing Data
#
# Pandas memungkinkan slicing data untuk memilih subnet dari kolom atau baris tertentu.
# 1. Slicing Baris dengan iloc
#
# Mengakses baris pertama hingga kedua (tidak termasuk beris ketika)
# print(df.iloc[0:2])
#
# sintaks
# df.iloc[start:stop]
#
# start : posisiawal (termasuk)
# stop: posisi akhir (tidak termasuk)
#
# 2. Slicing baris dengan iloc
# df.loc[start_label:stop_label]
#
# start_label : termasuk
# stop_label : tidak termasuk

# %%
df.iloc[0:2]
df.loc[2:3]
# Out:
#       Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur Wilayah
# 2  2025-10-09  03:45:22        4.8              15    -2.33  140.85   Papua
# 3  2025-10-08  22:11:45        3.9               5    -8.34  116.45  Lombok

# %% [markdown]
# 3. Slicing kolom dan baris
#
# mengakses baris pertama hingga ke dua dan kolom 'name' serta 'age'
# print(df.loc[0:1,['A','B]])
#
# df.loc[start_label:stop_label[list_kolom]]

# %%
df.loc[0:10,['Wilayah','Waktu']]
# Out:
#        Wilayah     Waktu
# 1       Banten  14:23:12
# 2        Papua  03:45:22
# ..         ...       ...
# 9   Yogyakarta  06:42:33
# 10       Ambon  09:55:12
#
# [10 rows x 2 columns]

# %% [markdown]
# Mengatur Index
# Mengatur indeks menggunakan kolom tertentu :
# df = df.set_index('A')
# Mengembalikan indeks ke default:
# df = df.reset_index()

# %%
df = df.reset_index()
df = df.set_index('Waktu')
df.head()
# Out:
#           index     Tanggal  Magnitudo  Kedalaman (km)  Lintang   Bujur  \
# Waktu
# 14:23:12      1  2025-10-10        5.2              10    -6.52  105.31
# 03:45:22      2  2025-10-09        4.8              15    -2.33  140.85
# 22:11:45      3  2025-10-08        3.9               5    -8.34  116.45
# 10:55:33      4  2025-10-07        5.5              25    -0.92   98.65
# 02:30:19      5  2025-10-06        4.3              12     3.58  126.78
#
#                Wilayah
# Waktu
# 14:23:12        Banten
# 03:45:22         Papua
# 22:11:45        Lombok
# 10:55:33      Mentawai
# 02:30:19  Maluku Utara

# %% [markdown]
# df = df.drop(columns=['level_0'])

# %%
df = df.set_index('index')

df.head()
# Out:
#           Tanggal  Magnitudo  Kedalaman (km)  Lintang   Bujur       Wilayah
# index
# 1      2025-10-10        5.2              10    -6.52  105.31        Banten
# 2      2025-10-09        4.8              15    -2.33  140.85         Papua
# 3      2025-10-08        3.9               5    -8.34  116.45        Lombok
# 4      2025-10-07        5.5              25    -0.92   98.65      Mentawai
# 5      2025-10-06        4.3              12     3.58  126.78  Maluku Utara

# %% [markdown]
# Filter dan Query Data
#
# 1. Filter data berdasarkan kondisi:
# filtered_df = df[df['Age'] > 30]

# %%
df = pd.read_excel(r"C:\Users\Kuneko\Downloads\Documents\Electronic_Product.xlsx",sheet_name="Electronics General")
df
# Out:
#             Product Name      Category   Brand     Model  Release Year  \
# 0    LG Smart TV 55 Inch            TV      LG  OLED55C3          2021
# 1      Sony Home Theater         Audio    Sony    HT-Z9F          2020
# ..                   ...           ...     ...       ...           ...
# 18        Fitbit Versa 3      Wearable  Fitbit  FB511BKE          2021
# 19  Dyson Pure Cool Link  Air Purifier   Dyson      TP04          2019
#
#     Power (W)  Price (USD)  Stock
# 0         150         1299      8
# 1         300          799     12
# ..        ...          ...    ...
# 18          5          229     25
# 19         40          599     10
#
# [20 rows x 8 columns]

# %%
df[df['Stock'] == 10]
# Out:
#             Product Name      Category  Brand      Model  Release Year  \
# 7        HP Spectre x360        Laptop     HP  13-bd0055          2021
# 8          Canon EOS 90D        Camera  Canon     90D-AP          2020
# 9              Nikon Z50        Camera  Nikon     Z50-20          2021
# 19  Dyson Pure Cool Link  Air Purifier  Dyson       TP04          2019
#
#     Power (W)  Price (USD)  Stock
# 7          65         1199     10
# 8          15          999     10
# 9          10          849     10
# 19         40          599     10

# %% [markdown]
# Menggunakan query untuk filter data :
# filtered_df = df.query ('Age > 30') ada karakter unik pake ``

# %%
df.query ('Stock > 30')
# Out:
#                Product Name          Category Brand    Model  Release Year  \
# 14  Roku Streaming Stick 4K  Streaming Device  Roku   3921RW          2021
# 15             JBL Charge 5           Speaker   JBL  CHARGE5          2022
#
#     Power (W)  Price (USD)  Stock
# 14          8           49     50
# 15         30          199     40

# %% [markdown]
# Filter dan Query Data
#
# 3. Filter dengan metode isin()
# metode isin() digunakan untuk memfilter data berdasarkan nilai dalam list atau collection. df[df['kolom'].isin([nilai1,nilai2, ...])]

# %%
df[df['Brand'].isin(['Roku','JBL', 'Sony'])]
# Out:
#                Product Name          Category Brand    Model  Release Year  \
# 1         Sony Home Theater             Audio  Sony   HT-Z9F          2020
# 14  Roku Streaming Stick 4K  Streaming Device  Roku   3921RW          2021
# 15             JBL Charge 5           Speaker   JBL  CHARGE5          2022
#
#     Power (W)  Price (USD)  Stock
# 1         300          799     12
# 14          8           49     50
# 15         30          199     40

# %% [markdown]
# Filter dan Query Data
# 4. Menggunakan str.contains untuk filter data dengan value string:
#
# metode str.contains() digunakan untuk memeriksa apakah sebuah string tertentu terdapat dalam nilai nilai kolom Dataframe
#
# filtered_df = df[df['name'].str.constains("budi",case=False)]

# %%
 df[df['Brand'].str.contains('Sony',case=False)]
# Out:
#         Product Name Category Brand   Model  Release Year  Power (W)  \
# 1  Sony Home Theater    Audio  Sony  HT-Z9F          2020        300
#
#    Price (USD)  Stock
# 1          799     12

# %% [markdown]
# Filtering data Query Data
# 5. Filter dengan Metode startswith()
# Metode  startswith() digunakan untuk memfilter data berdasarkan awalan string pada kolom tertentu.
# df[df['name'].str.startswith("budi")]

# %%
df[df['Model'].str.startswith("H")]
# Out:
#         Product Name           Category    Brand      Model  Release Year  \
# 1  Sony Home Theater              Audio     Sony     HT-Z9F          2020
# 5  Philips Air Fryer  Kitchen Appliance  Philips  HD9252/90          2021
#
#    Power (W)  Price (USD)  Stock
# 1        300          799     12
# 5       1500          199     20

# %% [markdown]
# Gabungan Filter
# Gunakan operatorlogika untuk gabungan:
# - AND (&) kedua kondisi harus benar
# - OR (|) salah satu kondisi benar
# - NOT (~) membalikan kondisi

# %%
df[(df['Stock'] > 5 ) | (df['Release Year'] > 2020)]
#bisa digunakan di query
# Out:
#             Product Name      Category   Brand     Model  Release Year  \
# 0    LG Smart TV 55 Inch            TV      LG  OLED55C3          2021
# 1      Sony Home Theater         Audio    Sony    HT-Z9F          2020
# ..                   ...           ...     ...       ...           ...
# 18        Fitbit Versa 3      Wearable  Fitbit  FB511BKE          2021
# 19  Dyson Pure Cool Link  Air Purifier   Dyson      TP04          2019
#
#     Power (W)  Price (USD)  Stock
# 0         150         1299      8
# 1         300          799     12
# ..        ...          ...    ...
# 18          5          229     25
# 19         40          599     10
#
# [20 rows x 8 columns]

# %% [markdown]
# Sorting Data
# sorting berdasarkan nilai kolom :
# df = df.sort_values('Price')
# sorting berdasarkan index:
# df = df.sort_index()

# %%
df_sort = df.sort_values('Price (USD)', ascending=True, inplace=true)

df_sort

#gunakan inplace untuk otomatis simpan sort
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_sort = df.sort_values('Price (USD)', ascending=True, inplace=true)
#       3 df_sort
#       5 #gunakan inplace untuk otomatis simpan sort
#
# NameError: name 'true' is not defined

# %%
df.sort_index(ascending=False)
# Out:
#             Product Name      Category   Brand     Model  Release Year  \
# 19  Dyson Pure Cool Link  Air Purifier   Dyson      TP04          2019
# 18        Fitbit Versa 3      Wearable  Fitbit  FB511BKE          2021
# ..                   ...           ...     ...       ...           ...
# 1      Sony Home Theater         Audio    Sony    HT-Z9F          2020
# 0    LG Smart TV 55 Inch            TV      LG  OLED55C3          2021
#
#     Power (W)  Price (USD)  Stock
# 19         40          599     10
# 18          5          229     25
# ..        ...          ...    ...
# 1         300          799     12
# 0         150         1299      8
#
# [20 rows x 8 columns]

# %%
df.sort_values(by=['Price (USD)', 'Stock'], ascending=[True,False])
# Out:
#                Product Name          Category  Brand     Model  Release Year  \
# 14  Roku Streaming Stick 4K  Streaming Device   Roku    3921RW          2021
# 13     Apple Magic Keyboard         Accessory  Apple    MK-MK2          2022
# ..                      ...               ...    ...       ...           ...
# 0       LG Smart TV 55 Inch                TV     LG  OLED55C3          2021
# 6               Dell XPS 13            Laptop   Dell      9310          2022
#
#     Power (W)  Price (USD)  Stock
# 14          8           49     50
# 13          5          129     25
# ..        ...          ...    ...
# 0         150         1299      8
# 6          65         1299      5
#
# [20 rows x 8 columns]

# %% [markdown]
# Menambah column
#
# df['nama_kolom_baru'] = value

# %%
# df['Price x Stok'] = 100 
df['Price x Stok'] = df['Price (USD)'] * df['Stock']
df
# Out:
#             Product Name      Category   Brand     Model  Release Year  \
# 0    LG Smart TV 55 Inch            TV      LG  OLED55C3          2021
# 1      Sony Home Theater         Audio    Sony    HT-Z9F          2020
# ..                   ...           ...     ...       ...           ...
# 18        Fitbit Versa 3      Wearable  Fitbit  FB511BKE          2021
# 19  Dyson Pure Cool Link  Air Purifier   Dyson      TP04          2019
#
#     Power (W)  Price (USD)  Stock  Price x Stok
# 0         150         1299      8         10392
# 1         300          799     12          9588
# ..        ...          ...    ...           ...
# 18          5          229     25          5725
# 19         40          599     10          5990
#
# [20 rows x 9 columns]

# %% [markdown]
# Menambah column baru dengan value berdasarkan kondisi value kolom lain
#
# df['nama_kolom_baru'] = np.where(condition, value_if_true, value_if_false)

# %%
import numpy as np

df['Status stock'] = np.where(df['Stock'] < 10, 'Stock Darurat', 'Stock Aman')
df
# Out:
#             Product Name      Category   Brand     Model  Release Year  \
# 0    LG Smart TV 55 Inch            TV      LG  OLED55C3          2021
# 1      Sony Home Theater         Audio    Sony    HT-Z9F          2020
# ..                   ...           ...     ...       ...           ...
# 18        Fitbit Versa 3      Wearable  Fitbit  FB511BKE          2021
# 19  Dyson Pure Cool Link  Air Purifier   Dyson      TP04          2019
#
#     Power (W)  Price (USD)  Stock  Price x Stok   Status stock
# 0         150         1299      8         10392  Stock Darurat
# 1         300          799     12          9588     Stock Aman
# ..        ...          ...    ...           ...            ...
# 18          5          229     25          5725     Stock Aman
# 19         40          599     10          5990     Stock Aman
#
# [20 rows x 10 columns]

# %% [markdown]
# Menghapus column
#
# df.drop(columns=['price'], inplace=true)

# %%
df.drop(columns=['Stock'])
df
# Out:
#             Product Name      Category   Brand     Model  Release Year  \
# 0    LG Smart TV 55 Inch            TV      LG  OLED55C3          2021
# 1      Sony Home Theater         Audio    Sony    HT-Z9F          2020
# ..                   ...           ...     ...       ...           ...
# 18        Fitbit Versa 3      Wearable  Fitbit  FB511BKE          2021
# 19  Dyson Pure Cool Link  Air Purifier   Dyson      TP04          2019
#
#     Power (W)  Price (USD)  Stock  Price x Stok   Status stock
# 0         150         1299      8         10392  Stock Darurat
# 1         300          799     12          9588     Stock Aman
# ..        ...          ...    ...           ...            ...
# 18          5          229     25          5725     Stock Aman
# 19         40          599     10          5990     Stock Aman
#
# [20 rows x 10 columns]

# %% [markdown]
# Cara Mengubah Nama Kolom di Pandas Python
#
# Dalam Pandas, mengubah nama kolom pada DataFrame merupakan operasi yang sering dilakukan saat memproses data. Pandas menyediakan beberapa cara untuk melakukan ini, baik dengan mengubah semua nama kolom sekaligus, maupun mengubah satu atau beberapa kolom tertentu.
#
# 1. Menggunakan rename() Method
#
# digunakan untuk mengganti nama kolom secara spesifik. kita bisa menggunakan parameter columns untuk menentukan kolom mana yang ingin diubah.
#
# Sintaks Dasar:
#
#  df.rename(columns={'nama_lama' : 'nama_baru'}, inplace=True)
#
# 2. Menggantu Semua Nama Kolom dengan columns Property
#
# jika ingin mengganti semua nama kolom sekaligus kita bisa menggunakan properti columns.
#
# Sintaks Dasar :
#
#  df.columns = ['nama_baru1', 'nama_baru2', 'nama_baru3']

# %%
import pandas as pd
data = {

    'Nama': ['A', 'B', 'C'],
    'Usia': [ 25, 30, 22],
    'Kota':['Jakarta', 'Bandung', 'Surabaya']
}

df = pd.DataFrame(data)
df

df.rename(columns={'Nama' : 'Nama Lengkap'}, inplace=True)
df
# Out:
#   Nama Lengkap  Usia      Kota
# 0            A    25   Jakarta
# 1            B    30   Bandung
# 2            C    22  Surabaya

# %%
 df.columns = ['Nama', 'Usia Org', 'City']
 df
# Out:
#   Nama  Usia Org      City
# 0    A        25   Jakarta
# 1    B        30   Bandung
# 2    C        22  Surabaya

# %% [markdown]
# Bekerja pada data tanggal
#
# df['datatime'] = pd.to_datetime(df['datetime'])
#
# - get year = pd.to_datetime(dr['datetime']).dt.year
# - get month = pd.to_datetime(dr['datetime']).dt.month
# - get day = pd.to_datetime(dr['datetime']).dt.day

# %%
df = pd.read_json(r'C:\Users\Kuneko\Downloads\Documents\katalog_gempa.json')
df['Tanggal'] = pd.to_datetime(df['Tanggal']).dt.year
df
# Out:
#     Tanggal     Waktu  Magnitudo  Kedalaman (km)  Lintang   Bujur  \
# 0      2025  14:23:12        5.2              10    -6.52  105.31
# 1      2025  03:45:22        4.8              15    -2.33  140.85
# ..      ...       ...        ...             ...      ...     ...
# 18     2025  21:02:09        5.8              40    -3.33  100.11
# 19     2025  12:10:31        4.1              18    -1.55  120.12
#
#            Wilayah
# 0           Banten
# 1            Papua
# ..             ...
# 18  Sumatera Barat
# 19            Poso
#
# [20 rows x 7 columns]
